# %% [markdown]
# ## Prova di Informatica

# %%
#import librerie
import pandas as pd
import os

# %%
dataFrame = pd.read_csv("C:\\Users\\Portatile\\Desktop\\Fondamenti di informatica\\data.csv",low_memory=False)
dataFrame
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# 6405007       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00              NaN
#
# ...

# %% [markdown]
# #### Step 1
# Extract all trips with <font color = 'red'>trip_distance </font> larger than 50

# %%
trip50 = dataFrame.query('trip_distance>50')
trip50.head()
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 23842       2.0  2020-01-01 01:53:07   2020-01-01 03:54:41              1.0
# 39013       2.0  2020-01-01 02:05:07   2020-01-01 03:03:10              1.0
# 41620       1.0  2020-01-01 03:05:54   2020-01-01 04:16:26              1.0
# 58262       2.0  2020-01-01 05:36:12   2020-01-01 06:40:06              1.0
# 63024       2.0  2020-01-01 07:40:30   2020-01-01 08:40:01              1.0
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 23842          52.30         5.0                  N           262
# 39013          51.23         5.0                  N           264
# 41620          53.80         5.0                  N           132
# 58262          55.23         5.0                  N           132
# 63024          54.19         5.0                  N           132
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %% [markdown]
# #### Step 2
# Extract all trips where payment_type is missing

# %%
missing_payment = dataFrame[dataFrame["payment_type"].isna()]
missing_payment
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6339567       NaN  2020-01-01 08:51:00   2020-01-01 09:19:00              NaN
# 6339568       NaN  2020-01-01 08:38:43   2020-01-01 08:51:08              NaN
# 6339569       NaN  2020-01-01 08:27:00   2020-01-01 08:32:00              NaN
# 6339570       NaN  2020-01-01 08:46:00   2020-01-01 08:57:00              NaN
# 6339571       NaN  2020-01-01 08:21:00   2020-01-01 08:38:00              NaN
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# 6405007       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00              NaN
#
# ...

# %% [markdown]
# #### Step 3
# For each (<font color = red>PULocationID, DOLocationID </font>) pair, determine the number of trips

# %%
dataFrame.groupby(['PULocationID', 'DOLocationID']).size()
# Out:
# PULocationID  DOLocationID
# 1             1                638
#               50                 1
#               68                 1
#               138                2
#               140                1
#                               ...
# 265           259                2
#               261                1
#               263                4
#               264              317
#               265             2508
# Length: 31277, dtype: int64

# %% [markdown]
# #### Step 4
# Save all rows with missing <font color = 'red'>VendorID, passenger_count, store_and_fwd_flag, payment_type </font> in a new dataframe called <font color = 'red'>bad </font>, and remove those rows from the original dataframe.

# %%
bad = dataFrame.query('payment_type.isnull() | VendorID.isnull()| passenger_count.isnull()| store_and_fwd_flag.isnull()')
dataFrame = dataFrame.drop(bad.index)
dataFrame
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6339562       2.0  2020-01-31 23:38:07   2020-01-31 23:52:21              1.0
# 6339563       2.0  2020-01-31 23:00:18   2020-01-31 23:19:18              1.0
# 6339564       2.0  2020-01-31 23:24:22   2020-01-31 23:40:39              1.0
# 6339565       2.0  2020-01-31 23:44:22   2020-01-31 23:54:00              1.0
# 6339566       2.0  2020-01-31 23:19:37   2020-01-31 23:20:41              1.0
#
# ...

# %% [markdown]
# #### Step 5
# Add a duration column storing how long each trip has taken (use <font color = 'red'>tpep_pickup_datetime, tpep_dropoff_datetime</font>)

# %%
dataFrame['trip_duration'] = (pd.to_datetime(dataFrame['tpep_dropoff_datetime']) - pd.to_datetime(dataFrame['tpep_pickup_datetime']))#.dt.seconds
dataFrame.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# #### Step 6
# For each pickup location, determine how many trips have started there.

# %%
count_pick_up =  dataFrame.groupby(['PULocationID']).size()
count_pick_up
# Out:
# PULocationID
# 1         753
# 2           3
# 3          70
# 4        9902
# 5          39
#         ...
# 261     34229
# 262     85591
# 263    123997
# 264     43779
# 265      3090
# Length: 260, dtype: int64

# %% [markdown]
# #### Step 7
# Cluster the pickup time of the day into 30-minute intervals (e.g. from 02:00 to 02:30)

# %%
dataFrame['intervallo'] = pd.to_datetime(dataFrame['tpep_pickup_datetime']).dt.floor("30min")

# %% [markdown]
# #### Step 8
# For each interval, determine the average number of passengers and the average fare amount.

# %%
intervalli_df = dataFrame.groupby(["intervallo"]).mean(["passenger_count","fare_amount"])[["passenger_count", "fare_amount"]]
intervalli_df
# Out:
#                      passenger_count  fare_amount
# intervallo
# 2003-01-01 00:00:00         1.000000     0.000000
# 2008-12-31 23:00:00         2.000000    18.857143
# 2008-12-31 23:30:00         1.000000    22.666667
# 2009-01-01 00:00:00         1.777778    25.166667
# 2009-01-01 00:30:00         2.000000    24.250000
# ...                              ...          ...
# 2020-07-10 11:30:00         1.000000     7.000000
# 2020-07-31 18:30:00         1.000000     5.000000
# 2021-01-02 00:00:00         1.000000    10.500000
# 2021-01-02 00:30:00         1.000000    11.500000
# 2021-01-02 01:00:00         1.000000    10.000000
#
# [1539 rows x 2 columns]

# %% [markdown]
# #### Step 9
# For each payment type and each interval, determine the average fare amount

# %%
df_pay_int = dataFrame.groupby(["intervallo","payment_type"]).mean(["fare_amount"])[["fare_amount"]].reset_index()
df_pay_int
# Out:
#               intervallo  payment_type  fare_amount
# 0    2003-01-01 00:00:00           2.0          0.0
# 1    2008-12-31 23:00:00           1.0         13.5
# 2    2008-12-31 23:00:00           2.0         26.0
# 3    2008-12-31 23:30:00           1.0         52.0
# 4    2008-12-31 23:30:00           2.0          8.0
# ...                  ...           ...          ...
# 6007 2020-07-10 11:30:00           1.0          7.0
# 6008 2020-07-31 18:30:00           2.0          5.0
# 6009 2021-01-02 00:00:00           2.0         10.5
# 6010 2021-01-02 00:30:00           2.0         11.5
# 6011 2021-01-02 01:00:00           1.0         10.0
#
# [6012 rows x 3 columns]

# %% [markdown]
# #### Step 10
# For each payment type, determine the interval when the average fare amount is maximum

# %%
df_pay_int.loc[df_pay_int.groupby("payment_type")["fare_amount"].idxmax()].reset_index()
# Out:
#    index          intervallo  payment_type  fare_amount
# 0      3 2008-12-31 23:30:00           1.0      52.0000
# 1      6 2009-01-01 00:00:00           2.0      26.4375
# 2   2946 2020-01-16 03:30:00           3.0      45.8000
# 3   4304 2020-01-23 05:00:00           4.0      83.8000
# 4   4020 2020-01-21 17:30:00           5.0       0.0000

# %% [markdown]
# #### Step 11
# For each payment type, determine the interval when the overall ratio between the tip and the fare amounts is maximum

# %%
dataFrame = dataFrame[(dataFrame["fare_amount"] != 0) & (dataFrame["fare_amount"].notna()) & (dataFrame["tip_amount"].notna())]
dataFrame["ratio"] = dataFrame["tip_amount"] / dataFrame["fare_amount"]     
df11 = dataFrame[["intervallo","payment_type","tip_amount","fare_amount","ratio"]]
#df11.groupby("payment_type")["ratio"].idxmax()
df11.loc[df11.groupby("payment_type")["ratio"].idxmax()].reset_index(drop = True)
# Out:
#            intervallo  payment_type  tip_amount  fare_amount       ratio
# 0 2020-01-21 17:30:00           1.0      240.00         0.01  24000.0000
# 1 2020-01-19 13:30:00           2.0        1.75         4.00      0.4375
# 2 2020-01-01 21:00:00           3.0       40.00         2.50     16.0000
# 3 2020-01-27 17:00:00           4.0       -9.00        -2.50      3.6000

# %% [markdown]
# #### Step 12
# Find the location with the highest average fare amount

# %%
tmp = dataFrame[["PULocationID", "fare_amount"]].rename(columns = {"PULocationID":"Location"})
tmp2 =  dataFrame[["DOLocationID", "fare_amount"]].rename(columns = {"DOLocationID":"Location"})
new = pd.concat([tmp, tmp2], ignore_index=True)
max_location = new.groupby("Location").mean().idxmax()
max_location
# Out:
# fare_amount    204
# dtype: int64

# %% [markdown]
# #### Step 13
# Build a new dataframe (called <font color = 'red'>common</font>) where, for each pickup location we keep all trips to the 5 most common destinations (i.e. each pickup location can have different common destinations).

# %% [markdown]
# #### Step 14
# On the <font color = 'red'>common</font> dataframe, for each payment type and each interval, determine the average fare amount

# %% [markdown]
# #### Step 15
# Compute the difference of the average fare amount computed in the previous point with those computed at point 9.

# %% [markdown]
# #### Step 16
# Compute the ratio between the differences computed in the previous point and those computed in point 9. Note: you have to compute a ratio for each pair (payment type, interval).

# %% [markdown]
# #### Step 17
# Build chains of trips. Two trips are consecutive in a chain if:
# <dl>
# <dd>(a) they have the same VendorID,</dd>
# <dd>(b) the pickup location of the second trip is also the dropoff location of the first trip,</dd>
# <dd>(c) the pickup time of the second trip is after the dropoff time of the first trip</dd>
# <dd>(d) the pickup time of the second trip is at most 2 minutes later than the dropoff time of the first trip.</dd>
# </dl>
# *Hint: Add a column chain to the dataset. A chain can have more than two trips.*
